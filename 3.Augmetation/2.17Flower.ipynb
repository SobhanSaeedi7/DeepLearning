# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics

# %%
dataset_path = '/content/drive/MyDrive/datasets/17Flowers/train'

# %%
idg = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

dataset_train = idg.flow_from_directory(
    dataset_path,
    shuffle=True,
    subset='training',
    target_size=(224, 224)
)

dataset_validation = idg.flow_from_directory(
    dataset_path,
    shuffle=True,
    subset='validation',
    target_size=(224, 224)

)
# Out:
# Found 823 images belonging to 17 classes.
# Found 197 images belonging to 17 classes.

# %%
# image augmentation
idg = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

dataset_train_augmented = idg.flow_from_directory(
    dataset_path,
    shuffle=True,
    subset='training',
    target_size=(224, 224)
)

dataset_validation_augmented = idg.flow_from_directory(
    dataset_path,
    shuffle=True,
    subset='validation',
    target_size=(224, 224)

)
# Out:
# Found 823 images belonging to 17 classes.
# Found 197 images belonging to 17 classes.

# %%
model = models.Sequential([
    layers.Conv2D(64, (3, 3), strides=(2, 2), activation='relu', padding='same', input_shape=(224, 224, 3)),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3, 3), strides=(2, 2), activation='relu', padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(265, (3, 3), strides=(2, 2), activation='relu', padding='same'),
    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(1080, activation='relu'),
    layers.Dense(17, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
history = model.fit(dataset_train,
                    validation_data=dataset_validation,
                    epochs=25)
# Out:
# Epoch 1/25
# 26/26 [==============================] - 799s 31s/step - loss: 2.6935 - accuracy: 0.1045 - val_loss: 2.2236 - val_accuracy: 0.1929
# Epoch 2/25
# 26/26 [==============================] - 7s 257ms/step - loss: 2.2361 - accuracy: 0.2224 - val_loss: 1.7975 - val_accuracy: 0.3756
# Epoch 3/25
# 26/26 [==============================] - 6s 233ms/step - loss: 1.7479 - accuracy: 0.4119 - val_loss: 1.5408 - val_accuracy: 0.4416
# Epoch 4/25
# 26/26 [==============================] - 6s 230ms/step - loss: 1.4297 - accuracy: 0.4921 - val_loss: 1.3655 - val_accuracy: 0.4924
# Epoch 5/25
# 26/26 [==============================] - 7s 260ms/step - loss: 1.1487 - accuracy: 0.6160 - val_loss: 1.4774 - val_accuracy: 0.5127
# Epoch 6/25
# 26/26 [==============================] - 6s 235ms/step - loss: 0.9024 - accuracy: 0.7011 - val_loss: 1.3025 - val_accuracy: 0.5431
# Epoch 7/25
# 26/26 [==============================] - 7s 258ms/step - loss: 0.6756 - accuracy: 0.7424 - val_loss: 1.5765 - val_accuracy: 0.5381
# Epoch 8/25
# 26/26 [==============================] - 6s 233ms/step - loss: 0.5441 - accuracy: 0.8335 - val_loss: 1.2454 - val_accuracy: 0.6091
# Epoch 9/25
# 26/26 [==============================] - 7s 261ms/step - loss: 0.2812 - accuracy: 0.9259 - val_loss: 1.3532 - val_accuracy: 0.6447
# Epoch 10/25
# 26/26 [==============================] - 6s 234ms/step - loss: 0.2305 - accuracy: 0.9320 - val_loss: 1.6704 - val_accuracy: 0.6497
# Epoch 11/25
# 26/26 [==============================] - 7s 261ms/step - loss: 0.1643 - accuracy: 0.9550 - val_loss: 1.4545 - val_accuracy: 0.6751
# Epoch 12/25
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0480 - accuracy: 0.9915 - val_loss: 2.2167 - val_accuracy: 0.5787
# Epoch 13/25
# 26/26 [==============================] - 7s 277ms/step - loss: 0.2101 - accuracy: 0.9368 - val_loss: 1.7618 - val_accuracy: 0.5685
# Epoch 14/25
# 26/26 [==============================] - 6s 225ms/step - loss: 0.1249 - accuracy: 0.9587 - val_loss: 1.5410 - val_accuracy: 0.6396
# Epoch 15/25
# 26/26 [==============================] - 6s 229ms/step - loss: 0.0524 - accuracy: 0.9842 - val_loss: 1.5841 - val_accuracy: 0.6396
# Epoch 16/25
# 26/26 [==============================] - 7s 262ms/step - loss: 0.0280 - accuracy: 0.9951 - val_loss: 1.5521 - val_accuracy: 0.6396
# Epoch 17/25
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.6805 - val_accuracy: 0.6599
# Epoch 18/25
# 26/26 [==============================] - 7s 258ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.6883 - val_accuracy: 0.6701
# Epoch 19/25
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.7060 - val_accuracy: 0.6751
# Epoch 20/25
# 26/26 [==============================] - 7s 252ms/step - loss: 9.2617e-04 - accuracy: 1.0000 - val_loss: 1.7389 - val_accuracy: 0.6650
# Epoch 21/25
# 26/26 [==============================] - 6s 233ms/step - loss: 7.8116e-04 - accuracy: 1.0000 - val_loss: 1.7532 - val_accuracy: 0.6650
# Epoch 22/25
# 26/26 [==============================] - 6s 234ms/step - loss: 6.7440e-04 - accuracy: 1.0000 - val_loss: 1.7907 - val_accuracy: 0.6650
# Epoch 23/25
# 26/26 [==============================] - 6s 237ms/step - loss: 5.9489e-04 - accuracy: 1.0000 - val_loss: 1.8005 - val_accuracy: 0.6650
# Epoch 24/25
# 26/26 [==============================] - 7s 261ms/step - loss: 5.2493e-04 - accuracy: 1.0000 - val_loss: 1.8244 - val_accuracy: 0.6650
# Epoch 25/25
# 26/26 [==============================] - 6s 243ms/step - loss: 4.6991e-04 - accuracy: 1.0000 - val_loss: 1.8445 - val_accuracy: 0.6650

# %%
history_augmented = model.fit(dataset_train_augmented,
                    validation_data=dataset_validation_augmented,
                    epochs=25)
# Out:
# Epoch 1/25
# 26/26 [==============================] - 18s 705ms/step - loss: 1.2024 - accuracy: 0.6586 - val_loss: 1.3450 - val_accuracy: 0.5330
# Epoch 2/25
# 26/26 [==============================] - 17s 676ms/step - loss: 0.8654 - accuracy: 0.7072 - val_loss: 1.2131 - val_accuracy: 0.6091
# Epoch 3/25
# 26/26 [==============================] - 18s 701ms/step - loss: 0.6618 - accuracy: 0.7861 - val_loss: 0.9949 - val_accuracy: 0.6548
# Epoch 4/25
# 26/26 [==============================] - 17s 673ms/step - loss: 0.5300 - accuracy: 0.8056 - val_loss: 1.2636 - val_accuracy: 0.6294
# Epoch 5/25
# 26/26 [==============================] - 18s 702ms/step - loss: 0.5365 - accuracy: 0.8202 - val_loss: 1.3512 - val_accuracy: 0.6193
# Epoch 6/25
# 26/26 [==============================] - 18s 690ms/step - loss: 0.4306 - accuracy: 0.8493 - val_loss: 1.2360 - val_accuracy: 0.7056
# Epoch 7/25
# 26/26 [==============================] - 17s 660ms/step - loss: 0.4493 - accuracy: 0.8457 - val_loss: 1.0185 - val_accuracy: 0.6802
# Epoch 8/25
# 26/26 [==============================] - 18s 691ms/step - loss: 0.3259 - accuracy: 0.8846 - val_loss: 1.1582 - val_accuracy: 0.6904
# Epoch 9/25
# 26/26 [==============================] - 17s 667ms/step - loss: 0.3062 - accuracy: 0.8943 - val_loss: 1.3509 - val_accuracy: 0.6650
# Epoch 10/25
# 26/26 [==============================] - 19s 749ms/step - loss: 0.3173 - accuracy: 0.8858 - val_loss: 1.3863 - val_accuracy: 0.6599
# Epoch 11/25
# 26/26 [==============================] - 17s 664ms/step - loss: 0.2403 - accuracy: 0.9186 - val_loss: 1.3060 - val_accuracy: 0.6853
# Epoch 12/25
# 26/26 [==============================] - 19s 723ms/step - loss: 0.2627 - accuracy: 0.9174 - val_loss: 0.9573 - val_accuracy: 0.7259
# Epoch 13/25
# 26/26 [==============================] - 17s 667ms/step - loss: 0.2210 - accuracy: 0.9259 - val_loss: 1.1255 - val_accuracy: 0.7208
# Epoch 14/25
# 26/26 [==============================] - 17s 660ms/step - loss: 0.2341 - accuracy: 0.9162 - val_loss: 1.4548 - val_accuracy: 0.6853
# Epoch 15/25
# 26/26 [==============================] - 19s 715ms/step - loss: 0.2218 - accuracy: 0.9186 - val_loss: 1.3190 - val_accuracy: 0.6802
# Epoch 16/25
# 26/26 [==============================] - 18s 678ms/step - loss: 0.2201 - accuracy: 0.9198 - val_loss: 1.4686 - val_accuracy: 0.6751
# Epoch 17/25
# 26/26 [==============================] - 19s 727ms/step - loss: 0.1917 - accuracy: 0.9283 - val_loss: 1.3215 - val_accuracy: 0.6701
# Epoch 18/25
# 26/26 [==============================] - 17s 669ms/step - loss: 0.2732 - accuracy: 0.9113 - val_loss: 0.9423 - val_accuracy: 0.7665
# Epoch 19/25
# 26/26 [==============================] - 18s 710ms/step - loss: 0.1514 - accuracy: 0.9478 - val_loss: 1.1021 - val_accuracy: 0.7310
# Epoch 20/25
# 26/26 [==============================] - 20s 752ms/step - loss: 0.1159 - accuracy: 0.9575 - val_loss: 1.5487 - val_accuracy: 0.6650
# Epoch 21/25
# 26/26 [==============================] - 17s 669ms/step - loss: 0.1642 - accuracy: 0.9405 - val_loss: 1.1935 - val_accuracy: 0.7107
# Epoch 22/25
# 26/26 [==============================] - 17s 666ms/step - loss: 0.1150 - accuracy: 0.9660 - val_loss: 1.2492 - val_accuracy: 0.7513
# Epoch 23/25
# 26/26 [==============================] - 17s 674ms/step - loss: 0.0823 - accuracy: 0.9745 - val_loss: 1.0823 - val_accuracy: 0.7107
# Epoch 24/25
# 26/26 [==============================] - 18s 716ms/step - loss: 0.0821 - accuracy: 0.9684 - val_loss: 1.0242 - val_accuracy: 0.7614
# Epoch 25/25
# 26/26 [==============================] - 19s 724ms/step - loss: 0.1012 - accuracy: 0.9684 - val_loss: 1.3053 - val_accuracy: 0.7360

# %%
idg = ImageDataGenerator(
    rescale=1./255
)

dataset_test = idg.flow_from_directory(
    '/content/drive/MyDrive/datasets/17Flowers/test',
    shuffle=True,
    subset='training',
    target_size=(224, 224)
)
# Out:
# Found 340 images belonging to 17 classes.

# %%
model.evaluate(dataset_test)
# Out:
# 11/11 [==============================] - 247s 25s/step - loss: 1.7148 - accuracy: 0.7088
# [1.7148360013961792, 0.7088235020637512]

# %%
model.save('17flower_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
Y_pred = []
Y_test = []

for i in range(11):
  for label in model.predict(dataset_test[i][0]):
    Y_pred.append(np.argmax(label))
  for label in dataset_test[i][1]:
    Y_test.append(np.argmax(label))

Y_pred = np.array(Y_pred)
Y_test = np.array(Y_test)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
confusion_matrix = metrics.confusion_matrix(Y_pred, Y_test)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels=dataset_test.class_indices)

cm_display.plot(cmap='YlGnBu', xticks_rotation=90)
plt.show()
